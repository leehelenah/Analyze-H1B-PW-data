# %% [markdown]
# ### Download the data from Zillow
# https://www.zillow.com/research/data/

# %% [markdown]
# ## All home - Price by Zipcode

# %% [markdown]
# Select </br>
# Data Type: ZHVI All Homes (SFR, Condo/Co-op) Times Series, Smoothed, Seasonally Adjusted </br>
# Geography: Zip
#
# Save As Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv

# %%
import pandas as pd

df_price = pd.read_csv('Zip_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
df_price
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         61639         0       10025        Zip        NY    NY
# 1         84654         1       60657        Zip        IL    IL
# 2         61637         2       10023        Zip        NY    NY
# 3         91982         3       77494        Zip        TX    TX
# 4         84616         4       60614        Zip        IL    IL
# ...         ...       ...         ...        ...       ...   ...
# 30518     66169     34430       20052        Zip        DC    DC
# 30519     89666     34430       72630        Zip        AR    AR
# 30520     62532     34430       12345        Zip        OR    OR
# 30521     87060     34430       66045        Zip        KS    KS
# 30522     58379     34430        1470        Zip        MA    MA
#
#                 City                             Metro            CountyName  \
# 0           New York       New York-Newark-Jersey City       New York County
# ...

# %%
df_price[['State','RegionName','2020-12-31']].head()
# Out:
#   State  RegionName  2020-12-31
# 0    NY       10025   1127372.0
# 1    IL       60657    502851.0
# 2    NY       10023   1485429.0
# 3    TX       77494    354939.0
# 4    IL       60614    642996.0

# %% [markdown]
# ## All home - Rent by Zipcode

# %% [markdown]
# Select </br>
# Data Type: ZORI(Smoothed, Seasonally Adjusted) - All houses plus Multifamily time series </br>
# Geography: Zipcode </br>
# </br>
# Save As Zip_ZORI_AllHomesPlusMultifamily_SSA.csv

# %%
df_rent = pd.read_csv('Zip_ZORI_AllHomesPlusMultifamily_SSA.csv')
df_rent.head()
# Out:
#    RegionID  RegionName  SizeRank       MsaName  2014-01  2014-02  2014-03  \
# 0     61639       10025         1  New York, NY   2889.0   2904.0   2919.0
# 1     84654       60657         2   Chicago, IL   1406.0   1411.0   1416.0
# 2     61637       10023         3  New York, NY   3003.0   3012.0   3022.0
# 3     91982       77494         4   Houston, TX   1390.0   1387.0   1384.0
# 4     84616       60614         5   Chicago, IL   1692.0   1697.0   1702.0
#
#    2014-04  2014-05  2014-06  ...  2020-10  2020-11  2020-12  2021-01  \
# 0   2934.0   2949.0   2963.0  ...   2954.0   2944.0   2934.0   2924.0
# 1   1422.0   1426.0   1431.0  ...   1597.0   1595.0   1593.0   1591.0
# 2   3031.0   3041.0   3050.0  ...   2949.0   2937.0   2925.0   2913.0
# 3   1381.0   1379.0   1376.0  ...   1378.0   1387.0   1395.0   1404.0
# 4   1707.0   1712.0   1716.0  ...   1922.0   1922.0   1922.0   1921.0
#
#    2021-02  2021-03  2021-04  2021-05  2021-06  2021-07
# ...

# %% [markdown]
# Since most of the salary data I have is from 2020, I would like take the price and rent at 2020-12 from Zillow. (I assume it does not flutuate too much in 2020.)
