# %% [markdown]
# ### Download the data from Zillow
# https://www.zillow.com/research/data/

# %% [markdown]
# ## All home - Price by county

# %% [markdown]
# Select </br>
# Data Type: ZHVI All Homes (SFR, Condo/Co-op) Times Series, Smoothed, Seasonally Adjusted </br>
# Geography: County
#
# Save As County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv

# %%
import pandas as pd

df = pd.read_csv('County_zhvi_uc_sfrcondo_tier_0.33_0.67_sm_sa_month.csv')
df
# Out:
#       RegionID  SizeRank          RegionName RegionType StateName State  \
# 0         3101         0  Los Angeles County     County        CA    CA
# 1          139         1         Cook County     County        IL    IL
# 2         1090         2       Harris County     County        TX    TX
# 3         2402         3     Maricopa County     County        AZ    AZ
# 4         2841         4    San Diego County     County        CA    CA
# ...        ...       ...                 ...        ...       ...   ...
# 2870       425      3101        Camas County     County        ID    ID
# 2871      1648      3102      Daggett County     County        UT    UT
# 2872      2345      3112     Hinsdale County     County        CO    CO
# 2873      1933      3122      Mineral County     County        CO    CO
# 2874      2518      3124     San Juan County     County        CO    CO
#
#                                  Metro  StateCodeFIPS  MunicipalCodeFIPS  \
# ...

# %% [markdown]
# ## All home - Rent by county

# %% [markdown]
# Select </br>
# Data Type: ZORI(Smoothed, Seasonally Adjusted) - All houses plus Multifamily time series </br>
# Geography: County </br>
# </br>
# Save As Metro_ZORI_AllHomesPlusMultifamily_SSA.csv

# %%
df = pd.read_csv('Metro_ZORI_AllHomesPlusMultifamily_SSA.csv')
df
# Out:
#      RegionID                          RegionName  SizeRank  2014-01  2014-02  \
# 0      102001                       United States         0   1356.0     1361
# 1      394913                        New York, NY         1   2205.0     2214
# 2      753899  Los Angeles-Long Beach-Anaheim, CA         2   1868.0     1879
# 3      394463                         Chicago, IL         3   1437.0     1441
# 4      394514               Dallas-Fort Worth, TX         4   1179.0     1182
# ..        ...                                 ...       ...      ...      ...
# 100    394549                          Durham, NC       104   1211.0     1214
# 101    394995                  Port St. Lucie, FL       119   1101.0     1109
# 102    394602                    Fort Collins, CO       159   1196.0     1202
# 103    394405                         Boulder, CO       162   1469.0     1477
# 104    394623                     Gainesville, GA       229    953.0      955
#
# ...
